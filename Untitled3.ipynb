# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import warnings

# %%
s=input(" ")
d="https://www.medifee.com/treatment/"
d1=d+s+'/'
l=requests.get(d1).text
s=BeautifulSoup(l,'html.parser')
Lowest_Cost=[i.text for i in s.select('div.text-right span#minCostVal ')]
# Out:
#  acl-surgery-cost

# %%
d1
# Out:
# 'https://www.medifee.com/treatment/acl-surgery-cost/'

# %%
l
# Out:
# '<script>console.log(\'Limit of API calls per day reached\');</script><!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="utf-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t\t<!--[if lt IE 9]>\n\t<script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>\n\t<script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>\n\t<![endif]-->\n\t<title>ACL Surgery Cost in India</title>\n\t\t\t<meta name="description" content="Looking for the ACL Surgery in India? Get estimated cost for ACL surgery at top Orthopedic hospitals and clinics in India." />\n\t\t\t<link rel="canonical" href="https://www.medifee.com/treatment/acl-surgery-cost/" />\n\t<link rel=\'next\' href=\'https://www.medifee.com/treatment/acl-surgery-cost/page=2\' />\n<meta name=\'robots\' content=\'index, follow, max-snippet:-1, max-video-preview:-1, max-image-preview:large\'>\t<!-- common header me
# ...

# %%
Lowest_Cost
# Out:
# ['80,000']
