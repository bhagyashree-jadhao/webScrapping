# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings ('ignore')
# Out:
# <function warnings.filterwarnings(action, message='', category=<class 'Warning'>, module='', lineno=0, append=False)>

# %%
d=pd.read_csv('C:\\Users\\j\\Desktop\\Heart_Analysis\\Heart.csv')

# %%
d
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    int64
#  7   RestECG     303 non-null    int64
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    int64
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    int64
#  12  Ca          299 non-null    float64
#  13  Thal        301 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 35.6+ KB

# %%
d.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
d.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
d.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs',
#        'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
d.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
d
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
d.describe()
# Out:
#               Age         Sex      RestBP        Chol         Fbs     RestECG  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868  131.689769  246.693069    0.148515    0.990099
# std      9.038662    0.467299   17.599748   51.776918    0.356198    0.994971
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     48.000000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     56.000000    1.000000  130.000000  241.000000    0.000000    1.000000
# 75%     61.000000    1.000000  140.000000  275.000000    0.000000    2.000000
# max     77.000000    1.000000  200.000000  564.000000    1.000000    2.000000
#
#             MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  299.000000
# mean   149.607261    0.326733    1.039604    1.600660    0.672241
# std     22.875003    0.469794    1.161075    0.616226    0.937438
# ...

# %%
type(d)
# Out:
# pandas.core.frame.DataFrame

# %%
np.dtype(d['Age'])
# Out:
# dtype('int64')

# %%
np.dtype(d['Sex'])
# Out:
# dtype('int64')

# %%
d.isnull()
# Out:
#        Age    Sex  ChestPain  RestBP   Chol    Fbs  RestECG  MaxHR  ExAng  \
# 0    False  False      False   False  False  False    False  False  False
# 1    False  False      False   False  False  False    False  False  False
# 2    False  False      False   False  False  False    False  False  False
# 3    False  False      False   False  False  False    False  False  False
# 4    False  False      False   False  False  False    False  False  False
# ..     ...    ...        ...     ...    ...    ...      ...    ...    ...
# 298  False  False      False   False  False  False    False  False  False
# 299  False  False      False   False  False  False    False  False  False
# 300  False  False      False   False  False  False    False  False  False
# 301  False  False      False   False  False  False    False  False  False
# 302  False  False      False   False  False  False    False  False  False
#
#      Oldpeak  Slope     Ca   Thal    AHD
# ...

# %%
d.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         2
# AHD          0
# dtype: int64

# %%
ca_mean=d['Ca'].mean()

# %%
d = d.fillna(d.median())
d.isnull().sum()
# Out:
# C:\Users\j\AppData\Local\Temp\ipykernel_7632\132765849.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d = d.fillna(d.median())
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           0
# Thal         2
# AHD          0
# dtype: int64

# %%
#d['Thal'].fillna('')
d[['ChestPain']].value_counts()
# Out:
# ChestPain
# asymptomatic    144
# nonanginal       86
# nontypical       50
# typical          23
# dtype: int64

# %%
for i in d['Thal']:
    
    print(i)
# Out:
# fixed
# normal
# reversable
# normal
# normal
# normal
# normal
# normal
# reversable
# reversable
# fixed
# normal
# fixed
# reversable
# reversable
# normal
# reversable
# normal
# normal
# normal
# normal
# normal
# normal
# reversable
# reversable
# normal
# normal
# normal
# normal
# reversable
# normal
# reversable
# normal
# reversable
# normal
# normal
# reversable
# fixed
# reversable
# normal
# reversable
# reversable
# normal
# normal
# normal
# reversable
# normal
# reversable
# normal
# normal
# normal
# reversable
# normal
# normal
# reversable
# reversable
# reversable
# reversable
# normal
# normal
# reversable
# normal
# reversable
# normal
# reversable
# reversable
# normal
# reversable
# reversable
# normal
# normal
# reversable
# reversable
# fixed
# normal
# normal
# reversable
# normal
# normal
# reversable
# normal
# normal
# normal
# reversable
# normal
# normal
# normal
# nan
# normal
# normal
# normal
# reversable
# reversable
# normal
# normal
# reversable
# ...

# %%
# fill na value
d = d.apply(lambda x: x.fillna(x.value_counts().index[0]))
d
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
d.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           0
# Thal         0
# AHD          0
# dtype: int64

# %%
# count duplicated value
d.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## count how many patient have heart dieses

# %%
d['AHD'].value_counts()
# Out:
# No     164
# Yes    139
# Name: AHD, dtype: int64

# %%
d
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %% [markdown]
# # Data Processing sep catogorical and numerice value

# %%
cate_val=[]
cont_val=[]
for i in d.columns:
    if d[i].nunique()<=10:
        cate_val.append(i)
    else:
        cont_val.append(i)

# %% [markdown]
# # encoding categorical data

# %%
cate_val
# Out:
# ['Sex', 'ChestPain', 'Fbs', 'RestECG', 'ExAng', 'Slope', 'Ca', 'Thal', 'AHD']

# %%
cont_val
# Out:
# ['Age', 'RestBP', 'Chol', 'MaxHR', 'Oldpeak']

# %%
d['Ca'].unique()
# Out:
# array([0., 3., 2., 1.])

# %%
## plot how paitent having heart disease and  
sns.countplot(x =d['AHD'], data = d)
# Out:
# <AxesSubplot: xlabel='AHD', ylabel='count'>

# %%
d['Sex'].value_counts()
# Out:
# 1    206
# 0     97
# Name: Sex, dtype: int64

# %% [markdown]
# # plot how many male and female

# %%
sns.countplot(x =d['Sex'], data = d)
plt.xticks([1,0],['Male','Female'])
plt.show()

# %% [markdown]
# # find gender distributation according to AHD variable

# %%
sns.countplot(x='Sex',hue='AHD',data=d)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels=['NO-Disease','Disease'])
plt.show()

# %% [markdown]
# # age distribution in the dataset

# %%
sns.distplot(d['Age'],bins=20)
plt.show()
# Out:
# C:\Users\j\AppData\Local\Temp\ipykernel_7632\4228915647.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['Age'],bins=20)

# %%
## most of the people has age 50 to 60

# %% [markdown]
# # chest pain type

# %%
c=d['ChestPain'].value_counts()

# %%
c
# Out:
# asymptomatic    144
# nonanginal       86
# nontypical       50
# typical          23
# Name: ChestPain, dtype: int64

# %%
sns.countplot(x =d['ChestPain'], data = d)
plt.show()

# %% [markdown]
# # chestpaint distribution  as per ahd variable

# %%
d.columns
# Out:
# Index(['Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs', 'RestECG', 'MaxHR',
#        'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
sns.countplot(x =d['ChestPain'],hue=d['AHD'], data = d)
plt.legend(labels=['NO-Disease','Disease'])
plt.show()

# %% [markdown]
# # show rest blood pressur

# %%
d['RestBP'].hist()
plt.show()

# %% [markdown]
# # show fasting blood sugar distribution according to Ahd variable

# %%
sns.countplot(x =d['Fbs'],hue=d['AHD'], data = d)
plt.legend(labels=['NO-Disease','Disease'])
plt.show()

# %% [markdown]
# ##op fbs is dibetics indicater id fbs is greater tha 120 is consider dibetics
# #Higher no of heart disease paitent without dibetice

# %% [markdown]
# # compare resting blood   as per sex column

# %%
sns.kdeplot(data=d, x="RestBP", hue="Sex", multiple="stack")
plt.legend(labels=['Male','Female'])
plt.show()

# %%
# Bp problem more in female as compare to male

# %%
sns.kdeplot(data=d, x="RestBP", hue="Sex", multiple="stack")
plt.legend(labels=['Male','Female'])
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_curve, roc_auc_score, classification_report, accuracy_score, confusion_matrix

# %% [markdown]
# # Replacing sring value by int

# %%
d['ChestPain']=d['ChestPain'].replace(['asymptomatic','nonanginal','nontypical','typical'],[1, 2,3,4])

# %%
d['ChestPain']
# Out:
# 0      4
# 1      1
# 2      1
# 3      2
# 4      3
#       ..
# 298    4
# 299    1
# 300    1
# 301    3
# 302    2
# Name: ChestPain, Length: 303, dtype: int64

# %%
d['Thal'].value_counts()
# Out:
# normal        168
# reversable    117
# fixed          18
# Name: Thal, dtype: int64

# %%
d['Thal']=d['Thal'].replace(['normal','reversable','fixed'],[0,1, 2])

# %%
d['Thal']
# Out:
# 0      2
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 298    1
# 299    1
# 300    1
# 301    0
# 302    0
# Name: Thal, Length: 303, dtype: int64

# %%
d
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          4     145   233    1        2    150      0      2.3
# 1     67    1          1     160   286    0        2    108      1      1.5
# 2     67    1          1     120   229    0        2    129      1      2.6
# 3     37    1          2     130   250    0        0    187      0      3.5
# 4     41    0          3     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 298   45    1          4     110   264    0        0    132      0      1.2
# 299   68    1          1     144   193    1        0    141      0      3.4
# 300   57    1          1     130   131    0        0    115      1      1.2
# 301   57    0          3     130   236    0        2    174      0      0.0
# 302   38    1          2     138   175    0        0    173      0      0.0
#
#      Slope   Ca  Thal  AHD
# 0        3  0.0     2   No
# ...

# %% [markdown]
# # Logistic regression

# %%
d.head()
# Out:
#    Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1          4     145   233    1        2    150      0      2.3
# 1   67    1          1     160   286    0        2    108      1      1.5
# 2   67    1          1     120   229    0        2    129      1      2.6
# 3   37    1          2     130   250    0        0    187      0      3.5
# 4   41    0          3     130   204    0        2    172      0      1.4
#
#    Slope   Ca  Thal  AHD
# 0      3  0.0     2   No
# 1      2  3.0     0  Yes
# 2      2  2.0     1  Yes
# 3      3  0.0     0   No
# 4      1  0.0     0   No

# %%
# Splitting 'Ahd column'

# %%
X=d.drop(columns='AHD',axis=1)
Y=d['AHD']

# %%
X
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          4     145   233    1        2    150      0      2.3
# 1     67    1          1     160   286    0        2    108      1      1.5
# 2     67    1          1     120   229    0        2    129      1      2.6
# 3     37    1          2     130   250    0        0    187      0      3.5
# 4     41    0          3     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 298   45    1          4     110   264    0        0    132      0      1.2
# 299   68    1          1     144   193    1        0    141      0      3.4
# 300   57    1          1     130   131    0        0    115      1      1.2
# 301   57    0          3     130   236    0        2    174      0      0.0
# 302   38    1          2     138   175    0        0    173      0      0.0
#
#      Slope   Ca  Thal
# 0        3  0.0     2
# ...

# %%
Y
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3       No
# 4       No
#       ...
# 298    Yes
# 299    Yes
# 300    Yes
# 301    Yes
# 302     No
# Name: AHD, Length: 303, dtype: object

# %%
#splitting data into traing data and test data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (303, 13) (242, 13) (61, 13)

# %%
model = LogisticRegression()

# %%
# training the LogisticRegression model with Training data
model.fit(X_train, Y_train)
# Out:
# C:\Users\j\anaconda3\envs\Heart_Project\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
training_data_accuracy
# Out:
# 0.871900826446281

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
test_data_accuracy
# Out:
# 0.819672131147541

# %%
input_data =(25,1,4,145,233,1,2,150,0,2.3,3,0.0,1)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 'No'):
  print('The Person  does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# ['Yes']
# The Person has Heart Disease
