# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings ('ignore')

# %%
f=requests.get("https://www.pristyncare.com/mobile-app/?af_xp=custom&source_caller=ui&pid=Website&utm_id=Medifee%20book%20Appt&utm_source=Website&shortlink=MedifeebookAppt&utm_medium=Medifee&utm_campaign=Medifee%20book%20Appt&c=Medifee%20Book%20Appointment/',headers=headers").text

# %%
f
# Out:
# '\n\n<!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><link rel="dns-prefetch" href="https://img.pristyncare.com" crossorigin><link rel="preconnect" href="https://img.pristyncare.com" crossorigin><link href="https://img.pristyncare.com/new_brand%2Felements%2Flogo.svg" rel="preload" as="image"><link href="https://img.pristyncare.com/New%20Homepage%20Images%2Fselect_city.svg" rel="preload" as="image"><link href="https://img.pristyncare.com/new_brand%2Felements%2Fpristyncare_favicon.png" rel="shortcut icon"><link href="https://img.pristyncare.com/new_brand%2Felements%2Fanup_and_prakash_raj.png" rel="preload" as="image"><link href="https://img.pristyncare.com/new_brand%2Felements%2Fanup_prakash_desktop.png" rel="preload" as="image"><link href="https://img.pristyncare.com/new_brand%2Felements%2FGlobe_icon-white.svg.png" rel="preload" as="image"><link href="https://img.pristyncare.com/HomePage%2FComponent%2017%20â\x80\x93%201%403x.png" rel="preload" as="image"><link href="https:/
# ...

# %%
soup=BeautifulSoup(f,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <link crossorigin="" href="https://img.pristyncare.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://img.pristyncare.com" rel="preconnect"/>\n  <link as="image" href="https://img.pristyncare.com/new_brand%2Felements%2Flogo.svg" rel="preload"/>\n  <link as="image" href="https://img.pristyncare.com/New%20Homepage%20Images%2Fselect_city.svg" rel="preload"/>\n  <link href="https://img.pristyncare.com/new_brand%2Felements%2Fpristyncare_favicon.png" rel="shortcut icon"/>\n  <link as="image" href="https://img.pristyncare.com/new_brand%2Felements%2Fanup_and_prakash_raj.png" rel="preload"/>\n  <link as="image" href="https://img.pristyncare.com/new_brand%2Felements%2Fanup_prakash_desktop.png" rel="preload"/>\n  <link as="image" href="https://img.pristyncare.com/new_brand%2Felements%2FGlobe_icon-white.svg.png" rel="preload"/>\n  <link as="image" href="https://img.pristyncare.com/HomePage%2FComponent%2017%20â
# ...

# %%
soup.find_all('h1')
# Out:
# [<h1>Pristyn Care Patient App is your one stop destination for all healthcare needs</h1>]

# %%
soup.select('div.navbar-collapse collapse')
# Out:
# []

# %%
soup.find_all('h1')[0].text
# Out:
# 'Pristyn Care Patient App is your one stop destination for all healthcare needs'

# %%
diesease=[i.text for i in soup.find_all('p')]

# %%
diesease
# Out:
# Select City
# Proctology
# Piles
# Anal Fistula
# Anal Fissure
# Pilonidal Sinus
# Laparoscopy
# Hernia
# Gallstone
# Inguinal Hernia
# Umbilical Hernia
# Appendicitis
# Gynaecology
# Ectopic Pregnancy
# Molar Pregnancy
# Bartholin Cyst
# Miscarriage
# Endometriosis
# Adenomyosis
# Vaginal Cyst
# PCOD/PCOS
# Ovarian Cyst
# Hymenoplasty
# Pregnancy Care
# Abortion
# Loose Vagina
# Uterus Removal
# Vaginoplasty
# Labiaplasty
# ENT
# Thyroid
# Adenoidectomy
# Tonsillectomy / Tonsil
# Ear Surgery
# Septoplasty
# Sinus Surgery
# Urology
# Enlarged Prostate
# Kidney Stones
# Hydrocele
# Phimosis
# Vascular
# Deep Vein Thrombosis
# Varicose Veins
# Varicocele
# Uterine Fibroids
# Diabetic Foot Ulcer
# AV Fistula
# Aesthetics
# Gynecomastia
# Breast Lift
# Axillary Breast
# Lipoma
# Breast Lump
# Hair Transplant
# Liposuction
# Breast Augmentation
# Breast Reduction
# Rhinoplasty
# Sebaceous Cyst
# Orthopedics
# Carpal Tunnel Syndrome
# ACL Tear
# Spine Surgery
# Bankart Surgery
# ...

# %%
l
# Out:
# [<div class="container">
#  <div class="navbar-header">
#  <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  </button>
#  <a href="/"><img alt="Medifee" class="navbar-brand" height="46" src="/images/medifee-logo.svg" width="125"/></a>
#  <div class="show-mobile align-items-center openBtn" id="mob-search" onclick="openSearch();"><span class="glyphicon glyphicon-search" style="color:#262F6C;font-size:20px;"></span></div>
#  </div>
#  <div class="navbar-collapse collapse">
#  <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" style="position: absolute;left: 83vw;font-family: Arial;font-size: 40px;line-height: 1;padding: 0;color: #fff;" type="button">x</button>
# ...

# %%
soup.select('ul.mp')
# Out:
# [<ul class="mp">
#  <li><a href="/treatment/abortion-cost/" title="Abortion Prices in India">Abortion</a></li>
#  <li><a href="/treatment/acl-surgery-cost/" title="ACL Surgery Prices in India">ACL Surgery</a></li>
#  <li><a href="/treatment/adenoids-surgery-cost/" title="Adenoidectomy Surgery Prices in India">Adenoidectomy</a></li>
#  <li><a href="/treatment/angiography-cost/" title="Angiography Prices in India">Angiography</a></li>
#  <li><a href="/treatment/angioplasty-cost/" title="Angioplasty Prices in India">Angioplasty</a></li>
#  <li><a href="/treatment/appendix-cost/" title="Appendix Surgery Prices in India">Appendix Surgery</a></li>
#  <li><a href="/treatment/arthroscopic-surgery-cost/" title="Arthroscopic Surgery Prices in India">Arthroscopic Surgery</a></li>
#  <li><a href="/treatment/bariatric-surgery-cost/" title="Bariatric Surgery Prices in India">Bariatric Surgery</a></li>
# ...

# %%
soup.select('li')
# Out:
# [<li class="dropdown">
#  <a class="dropdown-toggle" href="/treatment/">Treatment Cost<span class="caret-ang hide-mobile"></span></a>
#  <div class="show-mobile" data-toggle="dropdown" style="background-color: #242F6D;padding: 6px;position: absolute;right: 30px;top: 15px;border-radius: 2px;">
#  <span class="caret" style="border-top: 8px solid #ffffff; border-right: 6px solid transparent; border-left: 6px solid transparent;"></span>
#  </div>
#  <ul class="dropdown-menu" role="menu"><li>
#  <li><a href="/treatment/cataract-surgery-cost/">Cataract</a></li>
#  <li><a href="/treatment/fistula-surgery-cost/">Fistula</a></li>
#  <li><a href="/treatment/gynecomastia-surgery-cost/">Gynecomastia</a></li>
#  <li><a href="/treatment/hair-transplant-surgery-cost/">Hair Transplant</a></li>
#  <li><a href="/treatment/hernia-surgery-cost/">Hernia</a></li>
#  <li><a href="/treatment/kidney-stone-cost/">Kidney Stone</a></li>
# ...

# %%
movie_links=soup.select('td.titleColumn a')

# %%
r=soup.select('div.row')

# %%
diesease=[i.text for i in soup.select('div.row ul.mp li a ')]

# %%
soup.select('div.text-right')
# Out:
# [<div class="col-xs-12 col-sm-4 text-right">
#  <p class="copyright">All Content Copyright 2022. All Rights Reserved</p>
#  </div>]

# %%
soup.select("div.pristyn-btns hide-mobile form#searchform div.form-group d-flex align-items-center mr-10")
# Out:
# []

# %%
soup.select("input#search_query.form-control rinput")
# Out:
# []

# %%
link=[i for i in soup.select('div.row ul.mp li a')]

# %%
s='https://www.medifee.com/treatment/'

# %%
str1=input(" ")
s=s+str1
# Out:
#  abortion-cost

# %%
str1
# Out:
# 'abortion-cost'

# %%
d=requests.get("https://www.medifee.com/treatment/abortion-cost/").text

# %%
s=BeautifulSoup(d,'html.parser')

# %%
s
# Out:
# <script>console.log('Limit of API calls per day reached');</script><!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!--[if lt IE 9]>
# 	<script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
# 	<script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
# 	<![endif]-->
# <title>Abortion Cost in India</title>
# <meta content="Find out hospitals and clinics that offer Abortion in major Indian cities along with their prices." name="description">
# <link href="https://www.medifee.com/treatment/abortion-cost/" rel="canonical"/>
# <link href="https://www.medifee.com/treatment/abortion-cost/page=2" rel="next"/>
# <meta content="index, follow, max-snippet:-1, max-video-preview:-1, max-image-preview:large" name="robots"/> <!-- common header meta information -->
# ...

# %%
p=s.select('div.text-right span#minCostVal ')

# %%
Lowest_Cost=[i.text for i in s.select('div.text-right span#minCostVal ')]

# %%
p1=s.select('div.text-center span#avgCostVal')

# %%
Average_Cost =[i.text for i in s.select('div.text-center span#avgCostVal')]

# %%
Max_Cost =[i.text for i in s.select('div.text-left span#maxCostVal')]

# %%
Lowest_Cost=int(Lowest_Cost[0].replace(',',''))

# %%
Average_Cost=int(Average_Cost[0].replace(',',''))

# %%
Average_Cost
# Out:
# 30000

# %%
Max_Cost=int(Max_Cost[0].replace(',',''))

# %%
Max_Cost
# Out:
# 40000

# %%
treatments=pd.DataFrame()

# %%
#treatment=pd.DataFrame()
st=input(" ")
treatment=pd.DataFrame()
db={}
temp_data=pd.DataFrame(columns=['Diesease', 'Lowest_Cost','Average_Cost','Max_Cost'])
d="https://www.medifee.com/treatment/"
d1=d+st+'/'
l=requests.get(d1).text
s=BeautifulSoup(l,'html.parser')
Lowest_Cost=[i.text for i in s.select('div.text-right span#minCostVal ')]
#Lowest_Cost=int(Lowest_Cost[0].replace(',',''))
Average_Cost =[i.text for i in s.select('div.text-center span#avgCostVal')]
#Average_Cost=int(Average_Cost[0].replace(',',''))
Max_Cost =[i.text for i in s.select('div.text-left span#maxCostVal')]
#Max_Cost=int(Max_Cost[0].replace(',',''))
db['Diesease']=st[0:len(st)-5]
db['Lowest_Cost']=Lowest_Cost[0]
db['Average_Cost']=Average_Cost[0]
db['Max_Cost']=Max_Cost[0]

df=temp_data.append(db,ignore_index=True)
treatment=treatment.append(df,ignore_index=True)
treatments=treatments.append(treatment,ignore_index=True)
#return   treatment
# Out:
#  vascular-surgery-cost

# %%
treatments
# Out:
#                           Diesease Lowest_Cost Average_Cost  Max_Cost
# 0           gastric-bypass-surgery     280,000     4,40,000  6,00,000
# 1                      acl-surgery      80,000     1,20,000  1,66,788
# 2                 adenoids-surgery      40,000       70,000  1,20,000
# 3                         appendix      38,000     1,04,000  1,70,000
# 4                bariatric-surgery     250,000     3,50,000  6,00,000
# 5                      bph-surgery      60,000     1,00,000  1,50,000
# 6                   breast-implant     100,000     1,20,000  1,50,000
# 7              breast-lift-surgery      80,000       98,225  1,16,450
# 8            carpal-tunnel-surgery      60,000       65,000    70,000
# 9                  fissure-surgery      40,000       65,000  1,00,000
# 10     gallbladder-stone-operation      45,000       95,000  1,60,000
# 11                        glaucoma      26,000       30,000  1,70,000
# ...

# %%
gastric-bypass-surgery-cos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 gastric-bypass-surgery-cos
#
# NameError: name 'gastric' is not defined

# %%
#treatments.to_excel('Diesease.xlsx')
treatments.to_excel("Diesease.xlsx")

# %%
! pip install openpyxl
# Out:
# ...
#      -------------------------------------- 250.0/250.0 kB 1.1 MB/s eta 0:00:00
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...
